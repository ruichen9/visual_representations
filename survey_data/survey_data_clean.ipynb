# %%
import pandas as pd
import numpy as np

# %%
rate = pd.read_csv("Survey_raw.csv")

# %%
rate.head()
# Out:
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"America/De...
# 2                                2022-05-02 13:33:22
# 3                                2022-05-02 13:43:08
# 4                                2022-05-02 13:47:37
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 2                                2022-05-02 13:34:00                      1
# 3                                2022-05-02 13:48:21                      0
# 4                                2022-05-02 13:49:48                      0
#
#                   IPAddress                 Progress    Duration (in seconds)  \
# 0                IP Address                 Progress    Duration (in seconds)
# ...

# %%
rate = rate.iloc[:, range(17, 53)]

clean_rate = rate.iloc[3:36, :]

rate = clean_rate.to_numpy()

rate = rate.astype(np.float)

par_avg = np.nanmean(rate, axis = 0)

par_avg.shape

# %%
np.savetxt("avg.csv", par_avg, delimiter=",")
